# %%
import pandas as pd
import numpy as np
from swiss_code.data_viz import geospatial
import matplotlib.pyplot as plt
from tests import dataset_synth

# %% [markdown]
# ## `build_choropleth`

# %%
np.random.seed(1)
gdf = dataset_synth.simulate_gdf(100)

# %%
geospatial.build_choropleth(gdf, 4).head()
# Out:
#                                             geometry  value
# 0  POLYGON ((-119.99989 35.01256, -119.7527 35.01...    9.0
# 1  POLYGON ((-119.99989 35.25875, -119.7527 35.25...    1.0
# 2  POLYGON ((-119.99989 35.50494, -119.7527 35.50...   10.0
# 3  POLYGON ((-119.99989 35.75113, -119.7527 35.75...    7.0
# 4  POLYGON ((-119.7527 35.01256, -119.50551 35.01...    9.0

# %%
fig, ax = plt.subplots()
geospatial.build_choropleth(gdf, 4).plot(column='value',
                                       ax=ax,
                                       edgecolor='black',
                                       legend=True,
                                       cmap='coolwarm')
gdf.plot(ax=ax, markersize=10);
geospatial.label_gdf_polygons(geospatial.build_choropleth(gdf, 4), 'value', ax)
